# %%
import pandas as pd
import os
from typing import List, Dict

# %%
def read_csv_files(file_paths: List[str]) -> Dict[str, pd.DataFrame]:
    """
    Reads multiple CSV files and returns them as a dictionary of DataFrames.
    """
    dataframes = {}
    for file_path in file_paths:
        try:
            dataframes[file_path] = pd.read_csv(file_path)
        except Exception as e:
            print(f"Error reading file {file_path}: {e}")
    return dataframes

# %%
def compare_entries(dataframes: Dict[str, pd.DataFrame]) -> pd.DataFrame:
    """
    Compares the number of entries across DataFrames.
    """
    comparison = {
        "File Name": [],
        "Number of Entries": []
    }
    
    for file_name, df in dataframes.items():
        comparison["File Name"].append(file_name)
        comparison["Number of Entries"].append(len(df))
    
    return pd.DataFrame(comparison)

# %%
def compare_feature_counts(dataframes: Dict[str, pd.DataFrame], feature: str) -> pd.DataFrame:
    """
    Compares feature-based counts across DataFrames.
    """
    comparison = {}
    
    for file_name, df in dataframes.items():
        if feature in df.columns:
            feature_counts = df[feature].value_counts()
            comparison[file_name] = feature_counts
        else:
            print(f"Feature '{feature}' not found in {file_name}.")
    
    # Combine counts into a single DataFrame
    result = pd.concat(comparison, axis=1).fillna(0)
    result.columns = [f"{col} Count" for col in result.columns]
    return result

# %%
# Define file paths (update paths accordingly in Jupyter Notebook)
folder_path = "E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/"  # Change this to your folder containing CSV files
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Read the files
dataframes = read_csv_files(file_paths)

# %%
entries_comparison = compare_entries(dataframes)
print("Number of Entries Comparison:")
print(entries_comparison)
# Out:
# Number of Entries Comparison:
#                                            File Name  Number of Entries
# 0  E:/FAU/Thesis/Code/fl_client_splitting_shuvano...               5772
# 1  E:/FAU/Thesis/Code/fl_client_splitting_shuvano...               5772
# 2  E:/FAU/Thesis/Code/fl_client_splitting_shuvano...               5772
# 3  E:/FAU/Thesis/Code/fl_client_splitting_shuvano...               5772
# 4  E:/FAU/Thesis/Code/fl_client_splitting_shuvano...               5771

# %%
# Compare feature counts for a specific feature
feature = "is_PseudoFehler"  # Example feature to compare
feature_comparison = compare_feature_counts(dataframes, feature)
print(f"\nFeature Count Comparison for '{feature}':")
print(feature_comparison)
# Out:
# Feature Count Comparison for 'is_PseudoFehler':
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# is_PseudoFehler
# 0                                                             2974
# 1                                                             2798
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# is_PseudoFehler
# 0                                                             2906
# 1                                                             2866
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# is_PseudoFehler
# 0                                                             2952
# 1                                                             2820
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# is_PseudoFehler
# 0                                                             2880
# 1                                                             2892
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# is_PseudoFehler
# 0                                                             2944
# 1                                                             2827

# %%
def generate_feature_tables(dataframes: Dict[str, pd.DataFrame]) -> Dict[str, pd.DataFrame]:
    """
    Generates a table for all files and all features, showing counts for each unique value.
    """
    tables = {}

    for feature in dataframes[list(dataframes.keys())[0]].columns:  # Get features from the first dataframe
        feature_table = {}
        for file_name, df in dataframes.items():
            if feature in df.columns:
                feature_counts = df[feature].value_counts()
                feature_table[file_name] = feature_counts
            else:
                print(f"Feature '{feature}' not found in {file_name}.")
        
        # Combine counts into a single DataFrame
        combined_table = pd.concat(feature_table, axis=1).fillna(0)
        combined_table.columns = [f"{file} Count" for file in combined_table.columns.get_level_values(0)]
        tables[feature] = combined_table

    return tables

# %%
feature_tables = generate_feature_tables(dataframes)

# %%
# Display tables for each feature
for feature, table in feature_tables.items():
    print(f"\nFeature Table for '{feature}':")
    print(table)
# Out:
# Feature Table for 'imageIndex':
#             E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# imageIndex
# 17556                                                     1.0
# 15292                                                     1.0
# 6403                                                      1.0
# 2528                                                      1.0
# 28235                                                     1.0
# ...                                                       ...
# 9562                                                      0.0
# 12964                                                     0.0
# 5045                                                      0.0
# 11842                                                     0.0
# 24224                                                     0.0
#
#             E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# imageIndex
# 17556                                                     0.0
# 15292                                                     0.0
# 6403                                                      0.0
# 2528                                                      0.0
# 28235                                                     0.0
# ...                                                       ...
# 9562                                                      0.0
# 12964                                                     0.0
# 5045                                                      0.0
# 11842                                                     0.0
# 24224                                                     0.0
#
#             E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# imageIndex
# 17556                                                     0.0
# 15292                                                     0.0
# 6403                                                      0.0
# 2528                                                      0.0
# 28235                                                     0.0
# ...                                                       ...
# 9562                                                      0.0
# 12964                                                     0.0
# 5045                                                      0.0
# 11842                                                     0.0
# 24224                                                     0.0
#
#             E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# imageIndex
# 17556                                                     0.0
# 15292                                                     0.0
# 6403                                                      0.0
# 2528                                                      0.0
# 28235                                                     0.0
# ...                                                       ...
# 9562                                                      0.0
# 12964                                                     0.0
# 5045                                                      0.0
# 11842                                                     0.0
# 24224                                                     0.0
#
#             E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# imageIndex
# 17556                                                     0.0
# 15292                                                     0.0
# 6403                                                      0.0
# 2528                                                      0.0
# 28235                                                     0.0
# ...                                                       ...
# 9562                                                      1.0
# 12964                                                     1.0
# 5045                                                      1.0
# 11842                                                     1.0
# 24224                                                     1.0
#
# [28859 rows x 5 columns]
#
# Feature Table for 'typ':
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# typ
# ELLIPSE                                               5246
# RECT                                                   526
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# typ
# ELLIPSE                                               5217
# RECT                                                   555
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# typ
# ELLIPSE                                               5236
# RECT                                                   536
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# typ
# ELLIPSE                                               5224
# RECT                                                   548
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# typ
# ELLIPSE                                               5202
# RECT                                                   569
#
# Feature Table for 'errText':
#                       E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# errText
# Pin                                                              2291.0
# Meniskus                                                         1498.0
# Lötung                                                           1105.0
# Klemmträger verlötet                                              367.0
# Lotperle                                                          238.0
# solderbridge                                                      236.0
# Brücke                                                             22.0
# no solder                                                          15.0
# Perle                                                               0.0
# Loperle                                                             0.0
#
#                       E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# errText
# Pin                                                              2417.0
# Meniskus                                                         1398.0
# Lötung                                                           1036.0
# Klemmträger verlötet                                              399.0
# Lotperle                                                          223.0
# solderbridge                                                      258.0
# Brücke                                                             25.0
# no solder                                                          14.0
# Perle                                                               2.0
# Loperle                                                             0.0
#
#                       E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# errText
# Pin                                                              2336.0
# Meniskus                                                         1515.0
# Lötung                                                           1023.0
# Klemmträger verlötet                                              380.0
# Lotperle                                                          234.0
# solderbridge                                                      250.0
# Brücke                                                             16.0
# no solder                                                          17.0
# Perle                                                               1.0
# Loperle                                                             0.0
#
#                       E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# errText
# Pin                                                              2305.0
# Meniskus                                                         1446.0
# Lötung                                                           1085.0
# Klemmträger verlötet                                              409.0
# Lotperle                                                          249.0
# solderbridge                                                      244.0
# Brücke                                                             19.0
# no solder                                                          14.0
# Perle                                                               0.0
# Loperle                                                             1.0
#
#                       E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# errText
# Pin                                                              2332.0
# Meniskus                                                         1470.0
# Lötung                                                           1055.0
# Klemmträger verlötet                                              369.0
# Lotperle                                                          244.0
# solderbridge                                                      261.0
# Brücke                                                             26.0
# no solder                                                          14.0
# Perle                                                               0.0
# Loperle                                                             0.0
#
# Feature Table for 'errorClassCombined':
#                                 E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
0
# THT Bauteil verpolt                                                           0.0
#
#                                 E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# errorClassText
# PseudoFehler                                                               2866.0
# THT Loetstelle offen                                                        900.0
# THT Bauteil fehlt                                                           906.0
# THT Bauteil liegt nicht auf                                                 641.0
# THT Loetbruecke                                                             181.0
# THT Lotkugeln                                                               131.0
# THT Loetdurchstieg mangelhaft                                                82.0
# THT Loetst.Form mangelhaft                                                   44.0
# THT Bauteil versetzt                                                         16.0
# THT Bauteil mechan beschaedigt                                                4.0
# THT Bauteil Montage falsch                                                    0.0
# THT Bauteil falsch                                                            1.0
# THT Bauteil verpolt                                                           0.0
#
#                                 E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# errorClassText
# PseudoFehler                                                               2820.0
# THT Loetstelle offen                                                        977.0
# THT Bauteil fehlt                                                           920.0
# THT Bauteil liegt nicht auf                                                 581.0
# THT Loetbruecke                                                             182.0
# THT Lotkugeln                                                               133.0
# THT Loetdurchstieg mangelhaft                                                77.0
# THT Loetst.Form mangelhaft                                                   50.0
# THT Bauteil versetzt                                                         28.0
# THT Bauteil mechan beschaedigt                                                4.0
# THT Bauteil Montage falsch                                                    0.0
# THT Bauteil falsch                                                            0.0
# THT Bauteil verpolt                                                           0.0
#
#                                 E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# errorClassText
# PseudoFehler                                                               2892.0
# THT Loetstelle offen                                                       1006.0
# THT Bauteil fehlt                                                           829.0
# THT Bauteil liegt nicht auf                                                 603.0
# THT Loetbruecke                                                             161.0
# THT Lotkugeln                                                               136.0
# THT Loetdurchstieg mangelhaft                                                74.0
# THT Loetst.Form mangelhaft                                                   47.0
# THT Bauteil versetzt                                                         17.0
# THT Bauteil mechan beschaedigt                                                7.0
# THT Bauteil Montage falsch                                                    0.0
# THT Bauteil falsch                                                            0.0
# THT Bauteil verpolt                                                           0.0
#
#                                 E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# errorClassText
# PseudoFehler                                                               2827.0
# THT Loetstelle offen                                                       1009.0
# THT Bauteil fehlt                                                           844.0
# THT Bauteil liegt nicht auf                                                 644.0
# THT Loetbruecke                                                             174.0
# THT Lotkugeln                                                               132.0
# THT Loetdurchstieg mangelhaft                                                63.0
# THT Loetst.Form mangelhaft                                                   51.0
# THT Bauteil versetzt                                                         16.0
# THT Bauteil mechan beschaedigt                                                9.0
# THT Bauteil Montage falsch                                                    1.0
# THT Bauteil falsch                                                            0.0
# THT Bauteil verpolt                                                           1.0
#
# Feature Table for 'is_good':
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# is_good
# 0                                                     2978
# 1                                                     2794
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# is_good
# 0                                                     2913
# 1                                                     2859
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# is_good
# 0                                                     2962
# 1                                                     2810
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# is_good
# 0                                                     2887
# 1                                                     2885
#
#          E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# is_good
# 0                                                     2949
# 1                                                     2822
#
# Feature Table for 'is_PseudoFehler':
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data0.csv Count  \
# is_PseudoFehler
# 0                                                             2974
# 1                                                             2798
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data1.csv Count  \
# is_PseudoFehler
# 0                                                             2906
# 1                                                             2866
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data2.csv Count  \
# is_PseudoFehler
# 0                                                             2952
# 1                                                             2820
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data3.csv Count  \
# is_PseudoFehler
# 0                                                             2880
# 1                                                             2892
#
#                  E:/FAU/Thesis/Code/fl_client_splitting_shuvanon/fl_base_code/experiments/Baseline_feature_basednonenone_2025_01_07_04_39_32/data/data4.csv Count
# is_PseudoFehler
# 0                                                             2944
# 1                                                             2827
